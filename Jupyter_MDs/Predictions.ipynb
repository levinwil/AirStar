# %%
import sys
sys.path.append("../LearningModel/")
from freq_domain_mlp import *
import pickle
# Out:
# Using TensorFlow backend.

# %%
mlp = MLP()
mlp.set_model("/Users/williamlevine/Documents/BCI/AirStar/LearningModel/saved_models/Final_MLP.h5")

# %%
test_data = pickle.load(open("/Users/williamlevine/Downloads/mixture-trial-4.MultFeat"))
test_labels = test_data[1]
test_x = np.array([test_data[0]])

mlp.evaluate(test_x[0], test_labels, min_size = 50)
# Out:
# Performance on test data:
# Precision: 0.839330543933
# Recall: 0.717624612449
# F1: 0.773720750836
