# %%
import sys
sys.path.append("../LearningModel/")
from freq_domain_mlp import *
import pickle
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
mlp = MLP()
mlp.set_model("/Users/williamlevine/Documents/BCI/AirStar/LearningModel/saved_models/95-F1.h5")

# %%
test_data = pickle.load(open("/Users/williamlevine/Downloads/2-Seconds-Will-Trial-1.MultFeat"))
test_labels = test_data[1]
test_x = np.array([test_data[0]])
mlp.evaluate(test_x[0], test_labels, min_size = 170, display_feat = 1)
# Out:
# Performance on test data:
# Precision: 0.940425531915
# Recall: 0.858707170611
# F1: 0.897710487445
