# %%
import sys
sys.path.append("../LearningModel/")
from freq_domain_mlp import *
import pickle
import matplotlib.pyplot as plt
import time
# Out:
# Using TensorFlow backend.

# %%
mlp = MLP()
mlp.set_model("/Users/williamlevine/Documents/BCI/AirStar/LearningModel/saved_models/97-F1.h5")

# %%
test_data = pickle.load(open("/Users/williamlevine/Downloads/concat_train.MultFeat"))
test_labels = test_data[1]
test_x = np.array([test_data[0]])
plt.plot(test_x[0][34000:, 1])
plt.show()
#mlp.evaluate(test_x[0], test_labels, min_size = 170, display_feat = 1)

# %%
# %%time
mlp.predict_discrete(test_x[0, 0:2000])
# Out:
# CPU times: user 429 ms, sys: 47.9 ms, total: 477 ms
# Wall time: 237 ms
# array([0, 0, 0, ..., 0, 0, 0])
