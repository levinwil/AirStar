# %%
import sys
sys.path.append("../LearningModel/")
from freq_domain_mlp import *
import pickle
# Out:
# Using TensorFlow backend.

# %%
mlp = MLP()
mlp.set_model("/Users/williamlevine/Documents/BCI/AirStar/LearningModel/saved_models/Post-Savgol-MLP.h5")

# %%
test_data = pickle.load(open("/Users/williamlevine/Downloads/6-seconds-trial-1.MultFeat"))
test_labels = test_data[1]
test_x = np.array([test_data[0]])

mlp.evaluate(test_x[0], test_labels, min_size = 50, display_feat = 1)
# Out:
# Performance on test data:
# Precision: 0.87987012987
# Recall: 1.0
# F1: 0.93609671848
