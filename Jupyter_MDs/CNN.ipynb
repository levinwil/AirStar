# %%
import sys
sys.path.append("../LearningModel/")
sys.path.append("../pre-processing/")
from prepare_data import prepare_data
from utils import precision_recall_f1, train_test_split
import numpy as np
import pickle
import matplotlib.pyplot as plt
import freq_domain_cnn as CNN
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.local import LocallyConnected2D
from keras import backend as K

# %%
#validation on a completely different data set
train_data = pickle.load(open("/Users/williamlevine/Downloads/6-seconds-trial-1.MultFeat"))
train_labels = train_data[1]
train_x = np.array(train_data[0])
train_x = [prepare_data("/Users/williamlevine/Downloads/OpenBCI-RAW-Contract-Uncontract-6-seconds-trial-1.txt", return_freq_std_window = True, window = 36)[3][:-1006]]

# %%
cnn = CNN.CNN(36)
cnn.fit(train_x, train_labels, numClasses = 3, batch_size = 1000)
# Out:
# (1, 8025, 36)
# (8025, 'train samples')
# (2675, 'test samples')
# Train on 8025 samples, validate on 2675 samples
# Epoch 1/28
# 8025/8025 [==============================] - 4s - loss: 1.0780 - acc: 0.6465 - val_loss: 1.0412 - val_acc: 0.6262
# Epoch 2/28
# 8025/8025 [==============================] - 1s - loss: 0.9793 - acc: 0.6760 - val_loss: 0.9268 - val_acc: 0.6262
# Epoch 3/28
# 8025/8025 [==============================] - 1s - loss: 0.8629 - acc: 0.6760 - val_loss: 0.9215 - val_acc: 0.6262
# Epoch 4/28
# 8025/8025 [==============================] - 1s - loss: 0.8573 - acc: 0.6760 - val_loss: 0.9301 - val_acc: 0.6262
# Epoch 5/28
# 8025/8025 [==============================] - 1s - loss: 0.8576 - acc: 0.6760 - val_loss: 0.9286 - val_acc: 0.6262
# Epoch 6/28
# 8025/8025 [==============================] - 1s - loss: 0.8550 - acc: 0.6760 - val_loss: 0.9253 - val_acc: 0.6262
# Epoch 7/28
# 8025/8025 [==============================] - 1s - loss: 0.8567 - acc: 0.6760 - val_loss: 0.9222 - val_acc: 0.6262
# Epoch 8/28
# 8025/8025 [==============================] - 1s - loss: 0.8576 - acc: 0.6760 - val_loss: 0.9250 - val_acc: 0.6262
# Epoch 9/28
# 8025/8025 [==============================] - 1s - loss: 0.8565 - acc: 0.6760 - val_loss: 0.9285 - val_acc: 0.6262
# Epoch 10/28
# 8025/8025 [==============================] - 1s - loss: 0.8571 - acc: 0.6760 - val_loss: 0.9377 - val_acc: 0.6262
# Epoch 11/28
# 8025/8025 [==============================] - 1s - loss: 0.8568 - acc: 0.6760 - val_loss: 0.9274 - val_acc: 0.6262
# Epoch 12/28
# 8025/8025 [==============================] - 1s - loss: 0.8565 - acc: 0.6760 - val_loss: 0.9304 - val_acc: 0.6262
# Epoch 13/28
# 8025/8025 [==============================] - 1s - loss: 0.8559 - acc: 0.6760 - val_loss: 0.9212 - val_acc: 0.6262
# Epoch 14/28
# 8025/8025 [==============================] - 1s - loss: 0.8555 - acc: 0.6760 - val_loss: 0.9301 - val_acc: 0.6262
# Epoch 15/28
# 8025/8025 [==============================] - 1s - loss: 0.8535 - acc: 0.6760 - val_loss: 0.9214 - val_acc: 0.6262
# Epoch 16/28
# 8025/8025 [==============================] - 1s - loss: 0.8511 - acc: 0.6760 - val_loss: 0.9115 - val_acc: 0.6262
# Epoch 17/28
# 8025/8025 [==============================] - 1s - loss: 0.8438 - acc: 0.6760 - val_loss: 0.8945 - val_acc: 0.6262
# Epoch 18/28
# 8025/8025 [==============================] - 1s - loss: 0.8298 - acc: 0.6760 - val_loss: 0.8748 - val_acc: 0.6262
# Epoch 19/28
# 8025/8025 [==============================] - 1s - loss: 0.8098 - acc: 0.6760 - val_loss: 0.8448 - val_acc: 0.6262
# Epoch 20/28
# 8025/8025 [==============================] - 1s - loss: 0.7931 - acc: 0.6760 - val_loss: 0.8513 - val_acc: 0.6262
# Epoch 21/28
# 8025/8025 [==============================] - 2s - loss: 0.7823 - acc: 0.6761 - val_loss: 0.7983 - val_acc: 0.6273
# Epoch 22/28
# 8025/8025 [==============================] - 1s - loss: 0.7747 - acc: 0.6802 - val_loss: 0.8093 - val_acc: 0.6860
# Epoch 23/28
# 8025/8025 [==============================] - 1s - loss: 0.7712 - acc: 0.7055 - val_loss: 0.8780 - val_acc: 0.6703
# Epoch 24/28
# 8025/8025 [==============================] - 1s - loss: 0.7635 - acc: 0.7191 - val_loss: 0.7990 - val_acc: 0.6751
# Epoch 25/28
# 8025/8025 [==============================] - 1s - loss: 0.7438 - acc: 0.7341 - val_loss: 0.8613 - val_acc: 0.6778
# Epoch 26/28
# 8025/8025 [==============================] - 1s - loss: 0.7394 - acc: 0.7345 - val_loss: 0.8664 - val_acc: 0.5720
# Epoch 27/28
# 8025/8025 [==============================] - 1s - loss: 0.7314 - acc: 0.7222 - val_loss: 0.7595 - val_acc: 0.6845
# Epoch 28/28
# 8025/8025 [==============================] - 1s - loss: 0.7100 - acc: 0.7341 - val_loss: 0.7509 - val_acc: 0.6912
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-1e65606c954f> in <module>()
#       1 cnn = CNN.CNN(36)
# ----> 2 cnn.fit(train_x, train_labels, numClasses = 3, batch_size = 1000)
#
# /Users/williamlevine/Documents/BCI/AirStar/LearningModel/freq_domain_cnn.py in fit(self, X, labels, numClasses, test_size, batch_size, epochs, channels_present)
#     119         self.model = model
#     120         labels = [1 if y_test[i][1] > y_test[i][0] else 0
# --> 121             for i in range(10, len(y_test))]
#     122         x_test = np.array(x_test).reshape(1, x_test.shape[0], window)
#     123         self.evaluate(x_test, labels)
#
# NameError: global name 'window' is not defined

# %%
lr = LR.generateLR(train_x, train_labels)

# %%
#validation on a completely different data set
test_data = pickle.load(open("/Users/williamlevine/Downloads/mixture-trial-4.MultFeat"))
test_labels = test_data[1]
test_x = np.array(test_data[0])

# %%
predictions = LR.getPredictions(test_x, lr)

# %%
precision_recall_f1(np.abs(predictions), np.abs(test_labels), 50, 1)

# %%
plt.plot(test_x[:, 1])
plt.plot(predictions )
plt.show()
