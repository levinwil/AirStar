# %%
import sys
sys.path.append("../learning_model")
import pickle
import matplotlib.pyplot as plt
from analytical import predict
import numpy as np

# %%
test = pickle.load(open("C:/Users/levinwv1/Downloads/3-Seconds-Will-Trial-1.MultFeat"))
test_x = test[0]
test_y = test[1]

# %%
predictions = predict(test_x)

# %%
plt.plot(np.array(test_y))
plt.plot(predictions / 100)

plt.show()

# %%
together=  [train_x, train_y]

# %%
len(together[1])
# Out:
# 6900

# %%
pickle.dump([train_x, train_y], open("C:/Users/levinwv1/Downloads/2-Seconds-Will-Trial-1.MultFeat", 'wb'))
